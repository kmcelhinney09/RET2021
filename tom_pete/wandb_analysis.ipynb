# %%
import pandas as pd
import re

# %%
wandb_df = pd.read_csv("./wandb_disimilar_crossfold.csv")

for value in wandb_df["Name"]:
    full_name = value
    name = re.split("\d", value)[0]
    run_number = re.search("\d", value)[0]

    runs_of_same_pair
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [17], in <cell line: 3>()
#       3 for value in wandb_df["Name"]:
#       4     value_split = re.split("\d", value)
# ----> 5     name = value_split[0]
#       6     run_number = re.search("\d", value)[0]
#
# Input In [17], in <cell line: 3>()
#       3 for value in wandb_df["Name"]:
#       4     value_split = re.split("\d", value)
# ----> 5     name = value_split[0]
#       6     run_number = re.search("\d", value)[0]
#
# File ~/.local/share/JetBrains/Toolbox/apps/DataSpell/ch-0/221.5787.37/plugins/python-ce/helpers/pydev/_pydevd_bundle/pydevd_frame.py:747, in PyDBFrame.trace_dispatch(self, frame, event, arg)
#     745 # if thread has a suspend flag, we suspend with a busy wait
#     746 if info.pydev_state == STATE_SUSPEND:
# --> 747     self.do_wait_suspend(thread, frame, event, arg)
# ...
